# %%
#exploring various factors that may influence opening choices

import matplotlib.pyplot as plt
import seaborn as sns

from scripts import cleanup
df = cleanup.clean("../../data/raw/DataSet_aksingal.csv")
df
# Out:
#        rated winner  white_rating  black_rating  \
# 0      False  white          1500          1191
# 1       True  black          1322          1261
# 2       True  white          1496          1500
# 3       True  white          1439          1454
# 4       True  white          1523          1469
# ...      ...    ...           ...           ...
# 20053   True  white          1691          1220
# 20054   True  black          1233          1196
# 20055   True  white          1219          1286
# 20056   True  white          1360          1227
# 20057   True  black          1235          1339
#
#                                                    moves opening_eco  \
# 0      d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# 1      d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# 2      e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...         C20
# 3      d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...         D02
# 4      e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...         C41
# ...                                                  ...         ...
# 20053  d4 f5 e3 e6 Nf3 Nf6 Nc3 b6 Be2 Bb7 O-O Be7 Ne5...         A80
# 20054  d4 d6 Bf4 e5 Bg3 Nf6 e3 exd4 exd4 d5 c3 Bd6 Bd...         A41
# 20055  d4 d5 Bf4 Nc6 e3 Nf6 c3 e6 Nf3 Be7 Bd3 O-O Nbd...         D00
# 20056  e4 d6 d4 Nf6 e5 dxe5 dxe5 Qxd1+ Kxd1 Nd5 c4 Nb...         B07
# 20057  d4 d5 Bf4 Na6 e3 e6 c3 Nf6 Nf3 Bd7 Nbd2 b5 Bd3...         D00
#
#                                  opening_name  opening_ply
# 0            Slav Defense: Exchange Variation            5
# 1      Nimzowitsch Defense: Kennedy Variation            4
# 2       King's Pawn Game: Leonardis Variation            3
# 3      Queen's Pawn Game: Zukertort Variation            3
# 4                            Philidor Defense            5
# ...                                       ...          ...
# 20053                           Dutch Defense            2
# 20054                            Queen's Pawn            2
# 20055         Queen's Pawn Game: Mason Attack            3
# 20056                            Pirc Defense            4
# 20057         Queen's Pawn Game: Mason Attack            3
#
# [20058 rows x 8 columns]

# %%
#checking if there is a connection between different openings and game results
fig = plt.gcf()
fig.set_size_inches(50, 20)
sns.set(font_scale=5)
plot = sns.countplot(x="opening_eco", hue="winner", data = df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=40, ha="right", fontsize = 7)
plt.tight_layout()
plt.show()

# %%
#checking for relationship between opening used in rated vs unrated games
fig.set_size_inches(1000, 20)
sns.set(font_scale=2)
plot = sns.countplot(x="opening_eco", hue="rated", data = df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=40, ha="right", fontsize = 7)
plt.show()
