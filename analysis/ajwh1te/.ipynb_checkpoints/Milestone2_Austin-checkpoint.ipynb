# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../ajwh1te/scripts'))

# %%
path = "../../data/raw/DataSet_ajwh1te.csv"

from scripts import project_functions
df = project_functions.load_and_process(path)
df.head(1)
# Out:
#       turns victory_status winner  white_rating  black_rating moves  \
# 4828      1         resign  white          1670          1175    e4
#
#      opening_eco opening_name  opening_ply              date_start  \
# 4828         B00  King's Pawn            1 1970-01-01 00:24:32.750
#
#                     date_end length
# 4828 1970-01-01 00:24:32.750 0 days

# %%
#Possible ways to analyze the data
#Histogram
#Heat map
#Average rating + wins correlation

#1: Pandas Profiling 
#(May take a while)

import pandas_profiling
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof


#2: Describe?


#3: Pairplot 
#sns.pairplot(data=df)
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-11-13 04:34:54.999657&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
#Describe
df.head(1)
# Out:
#       turns victory_status winner  white_rating  black_rating moves  \
# 4828      1         resign  white          1670          1175    e4
#
#      opening_eco opening_name  opening_ply              date_start  \
# 4828         B00  King's Pawn            1 1970-01-01 00:24:32.750
#
#                     date_end length
# 4828 1970-01-01 00:24:32.750 0 days

# %%
#3: Pairplot

sns.pairplot(data=df, corner=True)

# %%
#Plot ideas:
#Ratings vs turns
#Ratings vs length of games
#Ratings vs victory
#Count of victory status
#Which colour more likely to win
#Count of opening plys of moves (Histogram??)

# %%
sns.scatterplot(data=df, x="black_rating", y="turns", color='Black')
# Out:
# <AxesSubplot:xlabel='black_rating', ylabel='turns'>

# %%
sns.scatterplot(data=df, x="white_rating", y="turns", color="grey")
# Out:
# <AxesSubplot:xlabel='white_rating', ylabel='turns'>

# %%
a = (sns
     .displot(data=df, x="victory_status")
    )

# %%
a = (sns
    .catplot(data=df, kind="count", x="winner", color="grey")
    )

# %%
a = (sns
    .catplot(data=df, kind='bar', y="white_rating", x="winner", color="lightgrey")
    )

# %%
a = (sns
    .catplot(data=df, kind='bar', y="black_rating", x="winner", color="grey")
    )

# %%
a = (sns
    .catplot(data=df, kind="count", x="opening_ply", palette="pastel")
    )
